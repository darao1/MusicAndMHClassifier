# %%
import pandas as pd

# %%
path = 'recent-grads.csv'
results = pd.read_csv(path)

# %%
results
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
pop = results.Total
pop
# Out:
# 0       2339
# 1        756
# 2        856
# 3       1258
# 4      32260
#        ...
# 168     8409
# 169     2854
# 170     2838
# 171     4626
# 172     1098
# Name: Total, Length: 173, dtype: int64

# %%
type(pop[0])
# Out:
# numpy.int64

# %%
#there are 173 Majors
len(results.Major.unique())
# Out:
# 173

# %%
1/173
# Out:
# 0.005780346820809248

# %%
def create_features(pop):
    return {'pop_feature':pop}

# %%
features_and_labels = zip(results.Total, results.Major)
features_and_labels

# %%
featuresets = [(create_features(pop), major) for pop, major in features_and_labels]
featuresets
# Out:
# [({'pop_feature': 2339}, 'PETROLEUM ENGINEERING'),
#  ({'pop_feature': 756}, 'MINING AND MINERAL ENGINEERING'),
#  ({'pop_feature': 856}, 'METALLURGICAL ENGINEERING'),
#  ({'pop_feature': 1258}, 'NAVAL ARCHITECTURE AND MARINE ENGINEERING'),
#  ({'pop_feature': 32260}, 'CHEMICAL ENGINEERING'),
#  ({'pop_feature': 2573}, 'NUCLEAR ENGINEERING'),
#  ({'pop_feature': 3777}, 'ACTUARIAL SCIENCE'),
#  ({'pop_feature': 1792}, 'ASTRONOMY AND ASTROPHYSICS'),
#  ({'pop_feature': 91227}, 'MECHANICAL ENGINEERING'),
#  ({'pop_feature': 81527}, 'ELECTRICAL ENGINEERING'),
#  ({'pop_feature': 41542}, 'COMPUTER ENGINEERING'),
#  ({'pop_feature': 15058}, 'AEROSPACE ENGINEERING'),
#  ({'pop_feature': 14955}, 'BIOMEDICAL ENGINEERING'),
#  ({'pop_feature': 4279}, 'MATERIALS SCIENCE'),
#  ({'pop_feature': 4321}, 'ENGINEERING MECHANICS PHYSICS AND SCIENCE'),
#  ({'pop_feature': 8925}, 'BIOLOGICAL ENGINEERING'),
#  ({'pop_feature': 18968}, 'INDUSTRIAL AND MANUFACTURING ENGINEERING'),
# ...

# %%
#setting up my training data and testing data

# %%
import random
random.shuffle(featuresets)

# %%
len(featuresets)
# Out:
# 173

# %%
173 * .8
# Out:
# 138.4

# %%
training_set = featuresets[:138]
testing_set = featuresets[138:]

# %%
training_set
# Out:
# [({'pop_feature': 209394}, 'NURSING'),
#  ({'pop_feature': 33599}, 'GENERAL MEDICAL AND HEALTH SERVICES'),
#  ({'pop_feature': 10972}, 'GEOLOGY AND EARTH SCIENCE'),
#  ({'pop_feature': 58001}, 'FAMILY AND CONSUMER SCIENCES'),
#  ({'pop_feature': 15232}, 'MICROBIOLOGY'),
#  ({'pop_feature': 128319}, 'COMPUTER SCIENCE'),
#  ({'pop_feature': 141951}, 'HISTORY'),
#  ({'pop_feature': 609}, 'MATHEMATICS AND COMPUTER SCIENCE'),
#  ({'pop_feature': 3014}, 'INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY'),
#  ({'pop_feature': 48246},
#   'FRENCH GERMAN LATIN AND OTHER COMMON FOREIGN LANGUAGE STUDIES'),
#  ({'pop_feature': 19735}, 'COMMUNITY AND PUBLIC HEALTH'),
#  ({'pop_feature': 18713}, 'MANAGEMENT INFORMATION SYSTEMS AND STATISTICS'),
#  ({'pop_feature': 24650}, 'INTERCULTURAL AND INTERNATIONAL STUDIES'),
#  ({'pop_feature': 41542}, 'COMPUTER ENGINEERING'),
#  ({'pop_feature': 17125}, 'SECONDARY TEACHER EDUCATION'),
#  ({'pop_feature': 856}, 'METALLURGICAL ENGINEERING'),
# ...

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
classifier.classify(create_features('609'))
# Out:
# 'VISUAL AND PERFORMING ARTS'

# %%
print(nltk.classify.accuracy(classifier,testing_set))
# Out:
# 0.0
