# %%
import pandas as pd

# %%
path = 'recent-grads.csv'
results = pd.read_csv(path)

# %%
results
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
major_category = results.Major_category
major_category
# Out:
# 0                   Engineering
# 1                   Engineering
# 2                   Engineering
# 3                   Engineering
# 4                   Engineering
#                  ...
# 168      Biology & Life Science
# 169    Psychology & Social Work
# 170    Psychology & Social Work
# 171    Psychology & Social Work
# 172                   Education
# Name: Major_category, Length: 173, dtype: object

# %%
major_category[0]
# Out:
# 'Engineering'

# %%
type(major_category[0])
# Out:
# str

# %%
#there are 173 Majors
len(results.Major.unique())
# Out:
# 173

# %%
#my classifier should have an accuracy of greater than 0.5%
#(this is the baseline for the algorithm)
1/173
# Out:
# 0.005780346820809248

# %%
#defining my features
#{"pop_feature": 2339}

# %%
#defining feature function, is this needed since dealing with floats?
#how to change to integers?
def create_features(total_number):
    return {'pop_feature':total_number[0]}

# %%
# combining my features column with my lables column (a tuple)
features_and_labels = zip(results.Major_category, results.Major)
features_and_labels

# %%
featuresets = [(create_features(x), y) for x, y in features_and_labels]
featuresets
# Out:
# [({'pop_feature': 'E'}, 'PETROLEUM ENGINEERING'),
#  ({'pop_feature': 'E'}, 'MINING AND MINERAL ENGINEERING'),
#  ({'pop_feature': 'E'}, 'METALLURGICAL ENGINEERING'),
#  ({'pop_feature': 'E'}, 'NAVAL ARCHITECTURE AND MARINE ENGINEERING'),
#  ({'pop_feature': 'E'}, 'CHEMICAL ENGINEERING'),
#  ({'pop_feature': 'E'}, 'NUCLEAR ENGINEERING'),
#  ({'pop_feature': 'B'}, 'ACTUARIAL SCIENCE'),
#  ({'pop_feature': 'P'}, 'ASTRONOMY AND ASTROPHYSICS'),
#  ({'pop_feature': 'E'}, 'MECHANICAL ENGINEERING'),
#  ({'pop_feature': 'E'}, 'ELECTRICAL ENGINEERING'),
#  ({'pop_feature': 'E'}, 'COMPUTER ENGINEERING'),
#  ({'pop_feature': 'E'}, 'AEROSPACE ENGINEERING'),
#  ({'pop_feature': 'E'}, 'BIOMEDICAL ENGINEERING'),
#  ({'pop_feature': 'E'}, 'MATERIALS SCIENCE'),
#  ({'pop_feature': 'E'}, 'ENGINEERING MECHANICS PHYSICS AND SCIENCE'),
#  ({'pop_feature': 'E'}, 'BIOLOGICAL ENGINEERING'),
#  ({'pop_feature': 'E'}, 'INDUSTRIAL AND MANUFACTURING ENGINEERING'),
# ...

# %%
#setting up my training data and testing data

# %%
import random
random.shuffle(featuresets)

# %%
#there are 735 items within my featuresets list
#i.e. 735 tuples of ages and streaming services
len(featuresets)
# Out:
# 173

# %%
#approx. 80% of a dataset should be used in a training set 
173 * .8
# Out:
# 138.4

# %%
#approx. 20% of a dataset should be used in a testing set
# this value is not really needed visually
173 * .2
# Out:
# 34.6

# %%
training_set = featuresets[:138]
testing_set = featuresets[138:]

# %%
#Time to build classifier!
training_set
# Out:
# [({'pop_feature': 'I'}, 'CONSTRUCTION SERVICES'),
#  ({'pop_feature': 'B'}, 'GENERAL BUSINESS'),
#  ({'pop_feature': 'L'}, 'PUBLIC POLICY'),
#  ({'pop_feature': 'E'}, 'SOCIAL SCIENCE OR HISTORY TEACHER EDUCATION'),
#  ({'pop_feature': 'E'}, 'GEOLOGICAL AND GEOPHYSICAL ENGINEERING'),
#  ({'pop_feature': 'L'}, 'PUBLIC ADMINISTRATION'),
#  ({'pop_feature': 'H'}, 'MEDICAL TECHNOLOGIES TECHNICIANS'),
#  ({'pop_feature': 'H'}, 'MISCELLANEOUS HEALTH MEDICAL PROFESSIONS'),
#  ({'pop_feature': 'A'}, 'AGRICULTURAL ECONOMICS'),
#  ({'pop_feature': 'S'}, 'INTERDISCIPLINARY SOCIAL SCIENCES'),
#  ({'pop_feature': 'E'}, 'LIBRARY SCIENCE'),
#  ({'pop_feature': 'B'}, 'MOLECULAR BIOLOGY'),
#  ({'pop_feature': 'S'}, 'MISCELLANEOUS SOCIAL SCIENCES'),
#  ({'pop_feature': 'P'}, 'OCEANOGRAPHY'),
#  ({'pop_feature': 'P'},
#   'NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL TECHNOLOGIES'),
#  ({'pop_feature': 'I'},
#   'ELECTRICAL, MECHANICAL, AND PRECISION TECHNOLOGIES AND PRODUCTION'),
# ...

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
classifier.classify(create_features(['Engineering']))
# Out:
# 'ZOOLOGY'

# %%
print(nltk.classify.accuracy(classifier,testing_set))
# Out:
# 0.0
